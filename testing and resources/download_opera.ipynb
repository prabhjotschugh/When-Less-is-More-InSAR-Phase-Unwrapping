# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#https://search.asf.alaska.edu/#/?dataset=OPERA-S1

# %%
# !python download-all-2025-09-04_05-39-08.py
# Out:
# No existing URS cookie found, please enter Earthdata username & password:
# (Credentials will not be stored, saved or logged anywhere)
#  > Cookiejar is bunk: None
# Username: manmeet
# Password (will not be displayed):
#  > attempting to download https://urs.earthdata.nasa.gov/profile
#  > 'Temporary' Redirect download @ Remote archive:
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir opera_buchanan

# %%
# !mv *.nc opera_buchanan/.

# %%
# !rm -rf *.*

# %%
# !du -sh opera_buchanan
# Out:
# 78G	opera_buchanan

# %%
# !mv opera_buchanan/ /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/
# Out:
# '0223 Publish FIR.pdf'
#  057042cc-professor-of-practice-advt-iiit-lucknow.gdoc
#  1100_yr_phase_coh.gslides
#  1243355616FCS-PROFORMA.doc
#  1365587855Annual_Work_Report_Part_A.docx
#  1422540080Revised_Proforma_reg_declaration_of_assets_and_liabilities_by_the_public_servants.gdoc
# '1504873203Deputation-form-Sep2017 (1).doc'
#  1547647125Immovable_Property_Return_form-2018.gdoc
#  1daypapers.gsheet
#  1-manmeet_UT-work_updates.gdoc
#  2-0100-Pie-Chart-Hierarchy-PGo-16_9.gslides
# '25-0124 - Singh - UTA (NSF) - Budget Justification.gdoc'
#  2pager_austin_climate_report.gdoc
# '78833_Affidavit for different appearance of names.gdoc'
#  A58_AIST_NASA.gdoc
#  abstract_cmip6_workshop_v3.gdoc
#  abstract_cmip6_workshop_v6.gdoc
# 'abstract_enso_monsoon (1).gdoc'
# 'abstract_enso_monsoon (2).gdoc'
#  abstract_enso_monsoon.docx
# 'abstract_enso_monsoon-final (1).gdoc'
#  abstract_enso_monsoon-final.docx
#  abstract_enso_monsoon-final.gdoc
#  abstract_enso_monsoon.gdoc
# ...
