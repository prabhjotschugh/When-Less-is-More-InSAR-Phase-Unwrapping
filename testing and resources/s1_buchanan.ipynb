# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !du -sh  /content/drive/MyDrive/flood/s1_VV_buchanan_dam_2018-01-01T003447_GeoTIFF.tif
# Out:
# 23M	/content/drive/MyDrive/flood/s1_VV_buchanan_dam_2018-01-01T003447_GeoTIFF.tif

# %%
# INSTALLING REQUIRED LIBRARIES
# !pip install -U pyproj -q
# !pip install -U utm -q
# !pip install -U google-colab -q
# !pip install -U tornado -q
# !pip install geemap -q
# !pip install wxee
# !pip install rioxarray pyproj
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 6.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# Collecting wxee
#   Downloading wxee-0.5.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.12/dist-packages (from wxee) (1.5.24)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from wxee) (1.5.2)
# Collecting rasterio (from wxee)
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from wxee) (2.32.4)
# Collecting rioxarray (from wxee)
#   Downloading rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from wxee) (4.67.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from wxee) (2025.8.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api->wxee) (2.19.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api->wxee) (2.181.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api->wxee) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api->wxee) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api->wxee) (0.30.0)
# Collecting affine (from rasterio->wxee)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->wxee) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->wxee) (2025.8.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->wxee) (8.2.1)
# Collecting cligj>=0.5 (from rasterio->wxee)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio->wxee) (2.0.2)
# Collecting click-plugins (from rasterio->wxee)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio->wxee) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->wxee) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->wxee) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->wxee) (2.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from rioxarray->wxee) (25.0)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.12/dist-packages (from rioxarray->wxee) (3.7.2)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray->wxee) (2.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->wxee) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->wxee) (4.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api->wxee) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api->wxee) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api->wxee) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray->wxee) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray->wxee) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray->wxee) (2025.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api->wxee) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api->wxee) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api->wxee) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->wxee) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->wxee) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->wxee) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->wxee) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray->wxee) (1.17.0)
# Downloading wxee-0.5.0-py3-none-any.whl (26 kB)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 57.6 MB/s eta 0:00:00
# Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 kB 4.7 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio, rioxarray, wxee
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 rasterio-1.4.3 rioxarray-0.19.0 wxee-0.5.0
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (3.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from rioxarray) (25.0)
# Requirement already satisfied: rasterio>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (1.4.3)
# Requirement already satisfied: xarray>=2024.7.0 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (2025.8.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (2.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj) (2025.8.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (25.3.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (8.2.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray) (3.2.3)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray>=2024.7.0->rioxarray) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2024.7.0->rioxarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2024.7.0->rioxarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2024.7.0->rioxarray) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray>=2024.7.0->rioxarray) (1.17.0)

# %%
import rasterio
import xarray as xr
import numpy as np

# Open the GeoTIFF
with rasterio.open("/content/drive/MyDrive/flood/s1_VV_buchanan_dam_2018-01-01T003447_GeoTIFF.tif") as src:
    data = src.read(1)  # first band
    transform = src.transform
    crs = src.crs

    # Reproject to EPSG:4326 if necessary
    if crs.to_epsg() != 4326:
        from rasterio.warp import calculate_default_transform, reproject, Resampling
        transform, width, height = calculate_default_transform(
            crs, "EPSG:4326", src.width, src.height, *src.bounds
        )
        kwargs = src.meta.copy()
        kwargs.update({
            "crs": "EPSG:4326",
            "transform": transform,
            "width": width,
            "height": height
        })

        data_reproj = np.empty((height, width), dtype=np.float32)
        reproject(
            source=rasterio.band(src, 1),
            destination=data_reproj,
            src_transform=src.transform,
            src_crs=src.crs,
            dst_transform=transform,
            dst_crs="EPSG:4326",
            resampling=Resampling.nearest
        )
        data = data_reproj

# Build coordinates
lon = np.arange(data.shape[1]) * transform.a + transform.c
lat = np.arange(data.shape[0]) * transform.e + transform.f

# Convert to xarray dataset
ds = xr.Dataset(
    {"variable": (["lat", "lon"], data)},
    coords={"lon": lon, "lat": lat},
)

# Save as NetCDF
ds.to_netcdf("output.nc")

# %%
# !ls
# Out:
# drive  output.nc  sample_data

# %%
ds = xr.open_dataset('/content/output.nc')
ds
# Out:
# <xarray.Dataset> Size: 232MB
# Dimensions:   (lat: 5009, lon: 5791)
# Coordinates:
#   * lon       (lon) float64 46kB -98.67 -98.67 -98.67 ... -98.15 -98.15 -98.15
#   * lat       (lat) float64 40kB 30.98 30.98 30.98 30.98 ... 30.53 30.53 30.53
# Data variables:
#     variable  (lat, lon) float64 232MB ...

# %%
ds.variable.plot()

# %%
# !ls /content/drive/MyDrive/flood
# Out:
# s1_VV_buchanan_dam_2018-01-01T003447_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-01-01T003512_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-01-25T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-01-25T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-02-06T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-02-06T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-02-18T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-02-18T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-02T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-02T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-14T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-14T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-26T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-03-26T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-04-07T003446_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-04-07T003511_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-01T003447_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-01T003512_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-13T003448_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-13T003513_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-25T003449_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-05-25T003514_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-06-18T003450_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-06-18T003515_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-06-30T003451_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-06-30T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-07-12T003451_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-07-12T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-07-24T003452_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-07-24T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-08-05T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-08-05T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-08-17T003454_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-09-10T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-09-10T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-09-22T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-09-22T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-10-04T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-10-04T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-10-28T003456_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-10-28T003521_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-11-09T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-11-09T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-11-21T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-11-21T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-12-03T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-12-03T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-12-27T003454_GeoTIFF.tif
# s1_VV_buchanan_dam_2018-12-27T003519_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-01-08T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-01-08T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-01-20T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-01-20T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-02-01T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-02-01T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-02-25T003452_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-02-25T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-03-09T003452_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-03-09T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-03-21T003452_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-03-21T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-02T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-02T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-14T003453_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-14T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-26T003454_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-04-26T003519_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-05-08T003454_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-05-08T003519_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-05-20T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-05-20T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-01T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-01T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-13T003455_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-13T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-14T123005_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-14T123034_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-19T003414_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-19T003443_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-20T123047_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-20T123116_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-25T003456_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-25T003521_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-26T123006_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-06-26T123035_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-07T003457_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-07T003522_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-19T003458_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-19T003523_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-31T003459_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-07-31T003524_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-08-12T003500_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-08-12T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-08-24T003500_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-08-24T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-05T003501_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-05T003526_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-17T003501_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-17T003526_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-29T003502_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-09-29T003527_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-10-11T003502_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-10-11T003527_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-10-23T003502_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-10-23T003527_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-04T003502_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-04T003527_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-16T003502_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-16T003527_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-28T003501_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-11-28T003526_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-12-10T003501_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-12-10T003526_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-12-22T003500_GeoTIFF.tif
# s1_VV_buchanan_dam_2019-12-22T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2020
003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-01-23T003542_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-02-04T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-02-04T003541_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-02-28T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-02-28T003541_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-03-12T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-03-12T003541_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-03-24T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-03-24T003541_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-05T003516_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-05T003541_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-17T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-17T003542_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-29T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-04-29T003542_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-05-11T003517_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-05-11T003542_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-05-23T003518_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-05-23T003543_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-04T003519_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-04T003544_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-16T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-16T003545_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-28T003520_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-06-28T003545_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-07-10T003521_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-07-10T003546_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-07-22T003522_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-07-22T003547_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-08-15T003523_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-08-15T003548_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-08-27T003524_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-08-27T003549_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-09-20T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-09-20T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-02T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-02T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-14T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-14T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-26T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-10-26T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-11-07T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-11-07T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-11-19T003525_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-11-19T003550_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-01T003524_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-01T003549_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-13T003524_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-13T003549_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-25T003523_GeoTIFF.tif
# s1_VV_buchanan_dam_2023-12-25T003548_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-06T003522_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-06T003547_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-18T003521_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-18T003546_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-30T003521_GeoTIFF.tif
# s1_VV_buchanan_dam_2024-01-30T003546_GeoTIFF.tif

# %%
import os
import rasterio
import xarray as xr
import numpy as np

# Directory containing the GeoTIFF files
input_directory = "/content/drive/MyDrive/flood/"
output_directory = "/content/drive/MyDrive/flood/"

# List all files in the directory
tif_files = [f for f in os.listdir(input_directory) if f.endswith(".tif")]

# Loop through each GeoTIFF file
for tif_file in tif_files:
    # Construct full file path
    tif_path = os.path.join(input_directory, tif_file)

    try:
        # Open the GeoTIFF
        with rasterio.open(tif_path) as src:
            data = src.read(1)  # first band
            transform = src.transform
            crs = src.crs

            # Reproject to EPSG:4326 if necessary
            if crs.to_epsg() != 4326:
                from rasterio.warp import calculate_default_transform, reproject, Resampling
                transform, width, height = calculate_default_transform(
                    crs, "EPSG:4326", src.width, src.height, *src.bounds
                )
                kwargs = src.meta.copy()
                kwargs.update({
                    "crs": "EPSG:4326",
                    "transform": transform,
                    "width": width,
                    "height": height
                })

                data_reproj = np.empty((height, width), dtype=np.float32)
                reproject(
                    source=rasterio.band(src, 1),
                    destination=data_reproj,
                    src_transform=src.transform,
                    src_crs=src.crs,
                    dst_transform=transform,
                    dst_crs="EPSG:4326",
                    resampling=Resampling.nearest
                )
                data = data_reproj

        # Build coordinates
        lon = np.arange(data.shape[1]) * transform.a + transform.c
        lat = np.arange(data.shape[0]) * transform.e + transform.f

        # Convert to xarray dataset
        ds = xr.Dataset(
            {"variable": (["lat", "lon"], data)},
            coords={"lon": lon, "lat": lat},
        )

        # Construct output file name with .nc extension
        nc_file = os.path.splitext(tif_file)[0] + ".nc"
        nc_path = os.path.join(output_directory, nc_file)

        # Save as NetCDF
        ds.to_netcdf(nc_path)
        print(f"Processed and saved: {nc_path}")

    except rasterio.errors.RasterioIOError as e:
        print(f"Error reading {tif_file}: {e}")
        continue  # Skip to the next file if there's an error
# Out:
# Processed and saved: /content/drive/MyDrive/flood/s1_VV_buchanan_dam_2018-01